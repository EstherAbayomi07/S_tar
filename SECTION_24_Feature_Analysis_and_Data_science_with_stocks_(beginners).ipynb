# %% [markdown]
# <a href="https://colab.research.google.com/github/EstherAbayomi07/S_tar/blob/main1/SECTION_24_Feature_Analysis_and_Data_science_with_stocks_(beginners).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SECTION 24

# !pip install yfinance  #it should show 'successfully installed'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.9/dist-packages (0.2.14)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.9/dist-packages (from yfinance) (40.0.1)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
import yfinance

stock_symbol = "TSLA"

start_date = "2016-01-01"

end_date = "2021-01-01"


dataset = yfinance.download(tickers = stock_symbol,
                  start = start_date,
                  end = end_date)

dataset
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   15.381333   15.425333   14.600000   14.894000   14.894000
# 2016-01-05   15.090667   15.126000   14.666667   14.895333   14.895333
# 2016-01-06   14.666667   14.670000   14.398667   14.602667   14.602667
# 2016-01-07   14.279333   14.562667   14.244667   14.376667   14.376667
# 2016-01-08   14.524000   14.696000   14.051333   14.066667   14.066667
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume
# Date
# 2016-01-04  102406500
# 2016-01-05   47802000
# 2016-01-06   56686500
# 2016-01-07   53314500
# 2016-01-08   54421500
# ...               ...
# 2020-12-24   68596800
# 2020-12-28   96835800
# 2020-12-29   68732400
# 2020-12-30  128538000
# 2020-12-31  148949700
#
# [1259 rows x 6 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2016-01-04 to 2020-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1259 non-null   float64
#  1   High       1259 non-null   float64
#  2   Low        1259 non-null   float64
#  3   Close      1259 non-null   float64
#  4   Adj Close  1259 non-null   float64
#  5   Volume     1259 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 68.9 KB

# %%
import numpy

dataset["Decrease"] = numpy.where(dataset["Volume"].shift(-1) > dataset["Volume"],
                                  1,
                                  0)

dataset
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   15.381333   15.425333   14.600000   14.894000   14.894000
# 2016-01-05   15.090667   15.126000   14.666667   14.895333   14.895333
# 2016-01-06   14.666667   14.670000   14.398667   14.602667   14.602667
# 2016-01-07   14.279333   14.562667   14.244667   14.376667   14.376667
# 2016-01-08   14.524000   14.696000   14.051333   14.066667   14.066667
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume  Decrease
# Date
# 2016-01-04  102406500         0
# 2016-01-05   47802000         1
# 2016-01-06   56686500         0
# 2016-01-07   53314500         1
# 2016-01-08   54421500         1
# ...               ...       ...
# 2020-12-24   68596800         1
# 2020-12-28   96835800         0
# 2020-12-29   68732400         1
# 2020-12-30  128538000         1
# 2020-12-31  148949700         0
#
# [1259 rows x 7 columns]

# %%
dataset["Increase"] = numpy.where(dataset["Volume"].shift(-1) < dataset["Volume"],
                                  0,
                                  1)

dataset
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   15.381333   15.425333   14.600000   14.894000   14.894000
# 2016-01-05   15.090667   15.126000   14.666667   14.895333   14.895333
# 2016-01-06   14.666667   14.670000   14.398667   14.602667   14.602667
# 2016-01-07   14.279333   14.562667   14.244667   14.376667   14.376667
# 2016-01-08   14.524000   14.696000   14.051333   14.066667   14.066667
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume  Decrease  Increase
# Date
# 2016-01-04  102406500         0         0
# 2016-01-05   47802000         1         1
# 2016-01-06   56686500         0         0
# 2016-01-07   53314500         1         1
# 2016-01-08   54421500         1         1
# ...               ...       ...       ...
# 2020-12-24   68596800         1         1
# 2020-12-28   96835800         0         0
# 2020-12-29   68732400         1         1
# 2020-12-30  128538000         1         1
# 2020-12-31  148949700         0         1
#
# [1259 rows x 8 columns]

# %%
dataset["Buy"] = numpy.where(dataset["Adj Close"].shift(-1) > dataset["Adj Close"], 
                                     1,
                                     -1)

dataset
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   15.381333   15.425333   14.600000   14.894000   14.894000
# 2016-01-05   15.090667   15.126000   14.666667   14.895333   14.895333
# 2016-01-06   14.666667   14.670000   14.398667   14.602667   14.602667
# 2016-01-07   14.279333   14.562667   14.244667   14.376667   14.376667
# 2016-01-08   14.524000   14.696000   14.051333   14.066667   14.066667
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume  Decrease  Increase  Buy
# Date
# 2016-01-04  102406500         0         0    1
# 2016-01-05   47802000         1         1   -1
# 2016-01-06   56686500         0         0   -1
# 2016-01-07   53314500         1         1   -1
# 2016-01-08   54421500         1         1   -1
# ...               ...       ...       ...  ...
# 2020-12-24   68596800         1         1    1
# 2020-12-28   96835800         0         0    1
# 2020-12-29   68732400         1         1    1
# 2020-12-30  128538000         1         1    1
# 2020-12-31  148949700         0         1   -1
#
# [1259 rows x 9 columns]

# %%
dataset["Returns"] = dataset["Adj Close"].pct_change()

dataset
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   15.381333   15.425333   14.600000   14.894000   14.894000
# 2016-01-05   15.090667   15.126000   14.666667   14.895333   14.895333
# 2016-01-06   14.666667   14.670000   14.398667   14.602667   14.602667
# 2016-01-07   14.279333   14.562667   14.244667   14.376667   14.376667
# 2016-01-08   14.524000   14.696000   14.051333   14.066667   14.066667
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume  Decrease  Increase  Buy   Returns
# Date
# 2016-01-04  102406500         0         0    1       NaN
# 2016-01-05   47802000         1         1   -1  0.000090
# 2016-01-06   56686500         0         0   -1 -0.019648
# 2016-01-07   53314500         1         1   -1 -0.015477
# 2016-01-08   54421500         1         1   -1 -0.021563
# ...               ...       ...       ...  ...       ...
# 2020-12-24   68596800         1         1    1  0.024443
# 2020-12-28   96835800         0         0    1  0.002901
# 2020-12-29   68732400         1         1    1  0.003466
# 2020-12-30  128538000         1         1    1  0.043229
# 2020-12-31  148949700         0         1   -1  0.015674
#
# [1259 rows x 10 columns]

# %%
dataset = dataset.dropna()

dataset
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-05   15.090667   15.126000   14.666667   14.895333   14.895333
# 2016-01-06   14.666667   14.670000   14.398667   14.602667   14.602667
# 2016-01-07   14.279333   14.562667   14.244667   14.376667   14.376667
# 2016-01-08   14.524000   14.696000   14.051333   14.066667   14.066667
# 2016-01-11   14.267333   14.296667   13.533333   13.856667   13.856667
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume  Decrease  Increase  Buy   Returns     Class
# Date
# 2016-01-05   47802000         1         1   -1  0.000090  Positive
# 2016-01-06   56686500         0         0   -1 -0.019648  Negative
# 2016-01-07   53314500         1         1   -1 -0.015477  Positive
# 2016-01-08   54421500         1         1   -1 -0.021563  Negative
# 2016-01-11   61371000         0         0    1 -0.014929  Negative
# ...               ...       ...       ...  ...       ...       ...
# 2020-12-24   68596800         1         1    1  0.024443  Positive
# 2020-12-28   96835800         0         0    1  0.002901  Negative
# 2020-12-29   68732400         1         1    1  0.003466  Negative
# 2020-12-30  128538000         1         1    1  0.043229  Positive
# 2020-12-31  148949700         0         1   -1  0.015674  Positive
#
# [1258 rows x 11 columns]

# %%
dataset["Class"] = numpy.where(dataset["Returns"].shift(-1) > dataset["Returns"],
                               "Negative",
                               "Positive")

dataset
# Out:
# <ipython-input-11-822d3495b43c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["Class"] = numpy.where(dataset["Returns"].shift(-1) > dataset["Returns"],
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-05   15.090667   15.126000   14.666667   14.895333   14.895333
# 2016-01-06   14.666667   14.670000   14.398667   14.602667   14.602667
# 2016-01-07   14.279333   14.562667   14.244667   14.376667   14.376667
# 2016-01-08   14.524000   14.696000   14.051333   14.066667   14.066667
# 2016-01-11   14.267333   14.296667   13.533333   13.856667   13.856667
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume  Decrease  Increase  Buy   Returns     Class
# Date
# 2016-01-05   47802000         1         1   -1  0.000090  Positive
# 2016-01-06   56686500         0         0   -1 -0.019648  Negative
# 2016-01-07   53314500         1         1   -1 -0.015477  Positive
# 2016-01-08   54421500         1         1   -1 -0.021563  Negative
# 2016-01-11   61371000         0         0    1 -0.014929  Negative
# ...               ...       ...       ...  ...       ...       ...
# 2020-12-24   68596800         1         1    1  0.024443  Positive
# 2020-12-28   96835800         0         0    1  0.002901  Negative
# 2020-12-29   68732400         1         1    1  0.003466  Negative
# 2020-12-30  128538000         1         1    1  0.043229  Positive
# 2020-12-31  148949700         0         1   -1  0.015674  Positive
#
# [1258 rows x 11 columns]

# %%
#perform exploratory Data Analysis
dataset.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean     34.219961    35.016940    33.397903    34.284686    34.284686
# std      40.138507    41.271609    38.959884    40.353248    40.353248
# min       9.488000    10.331333     9.403333     9.578000     9.578000
# 25%      15.777500    16.067501    15.508000    15.848500    15.848500
# 50%      20.506666    20.917333    20.129333    20.580334    20.580334
# 75%      23.868500    24.316833    23.479167    23.842999    23.842999
# max     233.330002   239.573334   230.373337   235.223328   235.223328
#
#              Volume     Decrease     Increase          Buy      Returns
# count  1.258000e+03  1258.000000  1258.000000  1258.000000  1258.000000
# mean   1.314686e+08     0.464229     0.465024     0.039746     0.002857
# std    9.230904e+07     0.498917     0.498974     0.999607     0.036401
# min    2.489250e+07     0.000000     0.000000    -1.000000    -0.210628
# 25%    7.166288e+07     0.000000     0.000000    -1.000000    -0.014340
# 50%    1.034415e+08     0.000000     0.000000     1.000000     0.001324
# 75%    1.561474e+08     1.000000     1.000000     1.000000     0.019224
# max    9.140820e+08     1.000000     1.000000     1.000000     0.198949

# %%
dataset.isnull().values.any()
# Out:
# False

# %%
dataset.groupby("Adj Close").size()
# Out:
# Adj Close
# 9.578000      1
# 9.866000      1
# 9.883333      1
# 10.031333     1
# 10.069333     1
#              ..
# 221.229996    1
# 221.996674    1
# 231.593338    1
# 231.666672    1
# 235.223328    1
# Length: 1233, dtype: int64

# %%
dataset.groupby("Class").size()
# Out:
# Class
# Negative    626
# Positive    632
# dtype: int64

# %%
import seaborn

seaborn.countplot(x = "Class",
                  data = dataset)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
#visializing data with different plots

# %%
import matplotlib.pyplot as pyplot


dataset.plot(kind = "box",
             subplots = True,
             layout = (20, 20),
             sharex = False,
             sharey = False,
             figsize = (20, 20))

pyplot.show()

# %%
dataset.hist(figsize = (20, 20))

pyplot.show()

# %%
dataset.plot(kind = "line",
             subplots = True,
             layout = (50, 50),
             sharex = False,
             sharey = False,
             figsize = (50, 50))

pyplot.show()

# %%
stock_prices = dataset[["Open", "High", "Low", "Adj Close"]]

pyplot.plot(stock_prices)

pyplot.legend(stock_prices)

pyplot.show()

# %%
pyplot.scatter(dataset["Open"], dataset["Close"])

pyplot.xlabel("Open")

pyplot.ylabel("Close")

pyplot.show()

# %%
pyplot.hist(dataset["High"], bins = 100)

pyplot.xlabel("High Price of Stock")

pyplot.ylabel("Frequency of Price Range")

pyplot.show()

# %%
dataset.plot(kind = "density",
             subplots = True,
             layout = (50, 50),
             sharex = False)

pyplot.show()

# %%
sizes = stock_prices.iloc[0]

column_names = ["Open", "High", "Low", "Adj Close"]


pyplot.pie(sizes,
           labels = column_names,
           autopct = "%.2f")

pyplot.show()

# %%
import seaborn 

pyplot.figure(figsize = (5,5))

seaborn.heatmap(dataset.corr())

pyplot.show()

# %%
dataset.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.999479  0.999351  0.998859   0.998859  0.275362
# High       0.999479  1.000000  0.999221  0.999552   0.999552  0.284936
# Low        0.999351  0.999221  1.000000  0.999353   0.999353  0.265948
# Close      0.998859  0.999552  0.999353  1.000000   1.000000  0.276411
# Adj Close  0.998859  0.999552  0.999353  1.000000   1.000000  0.276411
# Volume     0.275362  0.284936  0.265948  0.276411   0.276411  1.000000
# Decrease  -0.007601 -0.009551 -0.003440 -0.006472  -0.006472 -0.216126
# Increase   0.000308 -0.001647  0.004622  0.001468   0.001468 -0.215799
# Buy        0.044936  0.044705  0.044899  0.043758   0.043758  0.013233
# Returns    0.071846  0.084107  0.082557  0.096629   0.096629  0.111395
#
#            Decrease  Increase       Buy   Returns
# Open      -0.007601  0.000308  0.044936  0.071846
# High      -0.009551 -0.001647  0.044705  0.084107
# Low       -0.003440  0.004622  0.044899  0.082557
# Close     -0.006472  0.001468  0.043758  0.096629
# Adj Close -0.006472  0.001468  0.043758  0.096629
# Volume    -0.216126 -0.215799  0.013233  0.111395
# Decrease   1.000000  0.998403  0.045923 -0.002314
# Increase   0.998403  1.000000  0.044259 -0.001753
# Buy        0.045923  0.044259  1.000000 -0.030765
# Returns   -0.002314 -0.001753 -0.030765  1.000000

# %%
seaborn.pairplot(dataset, diag_kind = "kde", height = 2)

# %%
from bokeh.plotting import figure, output_notebook

from bokeh.io import show

output_notebook()

PLOT_SIDE_LENGTH = 500

bokeh_figure = figure(plot_width = PLOT_SIDE_LENGTH, plot_height = PLOT_SIDE_LENGTH)

bokeh_figure.line(dataset.index, dataset["Low"])

show(bokeh_figure)
# Out:
#   <div class="bk-root" id="e3266e74-5994-48b5-9f7b-c38795056495" data-root-id="1002"></div>

# %%
scatter_figure = figure(plot_width = PLOT_SIDE_LENGTH,
                        plot_height = PLOT_SIDE_LENGTH)

circle_x = dataset["Open"]

circle_y = dataset["Close"]

scatter_figure.circle(circle_x, circle_y)

square_x = dataset["High"]

square_y = dataset["Low"]

scatter_figure.square(square_x, square_y)

output_notebook()

show(scatter_figure)
# Out:
#   <div class="bk-root" id="1589d590-04fc-43a7-bfb3-f6bfa2bab4ec" data-root-id="1105"></div>

# %%
from mpl_toolkits import mplot3d

figure = pyplot.figure()

figure_axes = pyplot.axes(projection = "3d")

xdata = dataset["Open"]

ydata = dataset["High"]

zdata = dataset["Adj Close"]

pyplot.xlabel("Open")

pyplot.ylabel("High")

figure_axes.scatter3D(xdata,
                      ydata,
                      zdata)

# %%
from yellowbrick.features import Rank1D

features = dataset[["Open", "High", "Low", "Close", "Adj Close", "Volume", "Decrease","Increase", "Buy", "Returns", "Class"]]

features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2016-01-05 to 2020-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1258 non-null   float64
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Close      1258 non-null   float64
#  4   Adj Close  1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   Decrease   1258 non-null   int64
#  7   Increase   1258 non-null   int64
#  8   Buy        1258 non-null   int64
#  9   Returns    1258 non-null   float64
#  10  Class      1258 non-null   object
# dtypes: float64(6), int64(4), object(1)
# memory usage: 117.9+ KB

# %%
X = features.to_numpy( )

X
# Out:
# array([[ 1.50906668e+01,  1.51260004e+01,  1.46666670e+01, ...,
#          1.00000000e+00, -1.00000000e+00,  8.95150188e-05],
#        [ 1.46666670e+01,  1.46700001e+01,  1.43986673e+01, ...,
#          0.00000000e+00, -1.00000000e+00, -1.96481965e-02],
#        [ 1.42793331e+01,  1.45626669e+01,  1.42446671e+01, ...,
#          1.00000000e+00, -1.00000000e+00, -1.54766136e-02],
#        ...,
#        [ 2.20333328e+02,  2.23300003e+02,  2.18333328e+02, ...,
#          1.00000000e+00,  1.00000000e+00,  3.46552399e-03],
#        [ 2.24000000e+02,  2.32199997e+02,  2.22786667e+02, ...,
#          1.00000000e+00,  1.00000000e+00,  4.32288659e-02],
#        [ 2.33330002e+02,  2.39573334e+02,  2.30373337e+02, ...,
#          0.00000000e+00, -1.00000000e+00,  1.56739812e-02]])

# %%
y = dataset["Adj Close"].to_numpy()

y
# Out:
# array([ 14.89533329,  14.60266685,  14.37666702, ..., 221.99667358,
#        231.59333801, 235.22332764])

# %%
visualizer = Rank1D(features = features, algorithm = "shapiro")

visualizer.fit(X, y)

visualizer.transform(X)

visualizer.poof( )

# %%
from yellowbrick.features import Rank2D

visualizer_2D = Rank2D(features = features,
                       algorithm = "covariance")

visualizer_2D.fit(X, y)

visualizer_2D.transform(X)

visualizer_2D.poof( )

# %%
dataframe_objects = dataset.select_dtypes(include = ["object"]).copy()

dataframe_objects
# Out:
#                Class
# Date
# 2016-01-05  Positive
# 2016-01-06  Negative
# 2016-01-07  Positive
# 2016-01-08  Negative
# 2016-01-11  Negative
# ...              ...
# 2020-12-24  Positive
# 2020-12-28  Negative
# 2020-12-29  Negative
# 2020-12-30  Positive
# 2020-12-31  Positive
#
# [1258 rows x 1 columns]

# %%
dataframe_ints = dataset.select_dtypes(include = ["int"]).copy()

dataframe_ints
# Out:
#                Volume  Decrease  Increase  Buy
# Date
# 2016-01-05   47802000         1         1   -1
# 2016-01-06   56686500         0         0   -1
# 2016-01-07   53314500         1         1   -1
# 2016-01-08   54421500         1         1   -1
# 2016-01-11   61371000         0         0    1
# ...               ...       ...       ...  ...
# 2020-12-24   68596800         1         1    1
# 2020-12-28   96835800         0         0    1
# 2020-12-29   68732400         1         1    1
# 2020-12-30  128538000         1         1    1
# 2020-12-31  148949700         0         1   -1
#
# [1258 rows x 4 columns]

# %%
number_of_positive_returns = dataframe_objects[dataframe_objects == "Positive"].count().sum()

number_of_positive_returns
# Out:
# 632

# %%
number_of_negative_returns = dataframe_objects[dataframe_objects == "Negative"].count().sum()

number_of_negative_returns
# Out:
# 626

# %%
list_of_returns_counts = [number_of_positive_returns, number_of_negative_returns]

COLUMN_NAMES = ["Positive", "Negative"]

PIE_CHART_COLORS = ["orange", "blue"]

pyplot.pie(list_of_returns_counts,
           labels = COLUMN_NAMES,
           startangle = 90,
           colors = PIE_CHART_COLORS,
           autopct = "%.1f%%")

pyplot.show()

# %%
dataset.plot(kind = "hist",
             subplots = True,
             layout = (30, 30),
             sharex = False,
             sharey = False,
             figsize = (20, 20))

pyplot.show()
